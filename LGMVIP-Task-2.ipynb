# %%
import numpy as np
import pandas as pd
df = pd.read_csv("NSE-TATAGLOBAL.csv")
df
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-10-08  208.00  222.25  206.85  216.00  215.15
# 1     2018-10-05  217.00  218.60  205.90  210.25  209.20
# 2     2018-10-04  223.50  227.80  216.15  217.25  218.20
# 3     2018-10-03  230.00  237.50  225.75  226.45  227.60
# 4     2018-10-01  234.55  234.60  221.05  230.30  230.90
# ...          ...     ...     ...     ...     ...     ...
# 1230  2013-10-14  160.85  161.45  157.70  159.30  159.45
# 1231  2013-10-11  161.15  163.45  159.00  159.80  160.05
# 1232  2013-10-10  156.00  160.80  155.85  160.30  160.15
# 1233  2013-10-09  155.70  158.20  154.15  155.30  155.55
# 1234  2013-10-08  157.00  157.80  155.20  155.80  155.80
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                4642146.0         10062.83
# 1                3519515.0          7407.06
# 2                1728786.0          3815.79
# 3                1708590.0          3960.27
# 4                1534749.0          3486.05
# ...                    ...              ...
# 1230             1281419.0          2039.09
# 1231             1880046.0          3030.76
# 1232             3124853.0          4978.80
# 1233             2049580.0          3204.49
# 1234             1720413.0          2688.94
#
# [1235 rows x 8 columns]

# %%
df = df[::-1]
df
# Out:
#             Date    Open    High     Low    Last   Close  \
# 1234  2013-10-08  157.00  157.80  155.20  155.80  155.80
# 1233  2013-10-09  155.70  158.20  154.15  155.30  155.55
# 1232  2013-10-10  156.00  160.80  155.85  160.30  160.15
# 1231  2013-10-11  161.15  163.45  159.00  159.80  160.05
# 1230  2013-10-14  160.85  161.45  157.70  159.30  159.45
# ...          ...     ...     ...     ...     ...     ...
# 4     2018-10-01  234.55  234.60  221.05  230.30  230.90
# 3     2018-10-03  230.00  237.50  225.75  226.45  227.60
# 2     2018-10-04  223.50  227.80  216.15  217.25  218.20
# 1     2018-10-05  217.00  218.60  205.90  210.25  209.20
# 0     2018-10-08  208.00  222.25  206.85  216.00  215.15
#
#       Total Trade Quantity  Turnover (Lacs)
# 1234             1720413.0          2688.94
# 1233             2049580.0          3204.49
# 1232             3124853.0          4978.80
# 1231             1880046.0          3030.76
# 1230             1281419.0          2039.09
# ...                    ...              ...
# 4                1534749.0          3486.05
# 3                1708590.0          3960.27
# 2                1728786.0          3815.79
# 1                3519515.0          7407.06
# 0                4642146.0         10062.83
#
# [1235 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 1234 to 0
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  1235 non-null   object
#  1   Open                  1235 non-null   float64
#  2   High                  1235 non-null   float64
#  3   Low                   1235 non-null   float64
#  4   Last                  1235 non-null   float64
#  5   Close                 1235 non-null   float64
#  6   Total Trade Quantity  1235 non-null   float64
#  7   Turnover (Lacs)       1235 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 77.3+ KB

# %%
df.describe()
# Out:
#               Open         High          Low         Last        Close  \
# count  1235.000000  1235.000000  1235.000000  1235.000000  1235.000000
# mean    168.954858   171.429069   166.402308   168.736356   168.731053
# std      51.499145    52.436761    50.542919    51.587384    51.544928
# min     103.000000   104.600000   100.000000   102.600000   102.650000
# 25%     137.550000   138.925000   135.250000   137.175000   137.225000
# 50%     151.500000   153.250000   149.500000   151.200000   151.100000
# 75%     169.000000   172.325000   166.700000   169.100000   169.500000
# max     327.700000   328.750000   321.650000   325.950000   325.750000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          1.235000e+03      1235.000000
# mean           2.604151e+06      4843.166502
# std            2.277028e+06      5348.919832
# min            1.001800e+05       128.040000
# 25%            1.284482e+06      1801.035000
# 50%            1.964885e+06      3068.510000
# 75%            3.095788e+06      5852.600000
# max            2.919102e+07     55755.080000

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#             Date    Open    High     Low    Last   Close  \
# 1234  2013-10-08  157.00  157.80  155.20  155.80  155.80
# 1233  2013-10-09  155.70  158.20  154.15  155.30  155.55
# 1232  2013-10-10  156.00  160.80  155.85  160.30  160.15
# 1231  2013-10-11  161.15  163.45  159.00  159.80  160.05
# 1230  2013-10-14  160.85  161.45  157.70  159.30  159.45
# ...          ...     ...     ...     ...     ...     ...
# 4     2018-10-01  234.55  234.60  221.05  230.30  230.90
# 3     2018-10-03  230.00  237.50  225.75  226.45  227.60
# 2     2018-10-04  223.50  227.80  216.15  217.25  218.20
# 1     2018-10-05  217.00  218.60  205.90  210.25  209.20
# 0     2018-10-08  208.00  222.25  206.85  216.00  215.15
#
#       Total Trade Quantity  Turnover (Lacs)
# 1234             1720413.0          2688.94
# 1233             2049580.0          3204.49
# 1232             3124853.0          4978.80
# 1231             1880046.0          3030.76
# 1230             1281419.0          2039.09
# ...                    ...              ...
# 4                1534749.0          3486.05
# 3                1708590.0          3960.27
# 2                1728786.0          3815.79
# 1                3519515.0          7407.06
# 0                4642146.0         10062.83
#
# [1235 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
df_high = df.reset_index()['High']
df_high
# Out:
# 0       157.80
# 1       158.20
# 2       160.80
# 3       163.45
# 4       161.45
#          ...
# 1230    234.60
# 1231    237.50
# 1232    227.80
# 1233    218.60
# 1234    222.25
# Name: High, Length: 1235, dtype: float64

# %%
plt.plot(df_high)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

MMS = MinMaxScaler()
df_high = MMS.fit_transform(df_high.values.reshape(-1, 1))
df_high
# Out:
# array([[0.23734107],
#        [0.23912559],
#        [0.25072496],
#        ...,
#        [0.54963194],
#        [0.508588  ],
#        [0.52487174]])

# %%
train_size = int(len(df_high) * 0.8)
test_size = len(df_high) - train_size

train_size, test_size
# Out:
# (988, 247)

# %%
train_data, test_data = df_high[:train_size, :], df_high[train_size:, :1]
train_data.shape
# Out:
# (988, 1)

# %%
# Previous 100 data points are stored 

def create_data(data, time_step):
  X_data, y_data = [], []

  for i in range(len(data) - time_step - 1):
    prev = data[i: i+time_step, 0]
    X_data.append(prev)
    y_data.append(data[i+time_step, 0])

  return np.array(X_data), np.array(y_data)

# %%
time_step = 100

X_train, y_train = create_data(train_data, time_step)
X_test, y_test = create_data(test_data, time_step)

# %%
# Make 3-D data(LSTM Requirement) (samples, time steps, features)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_train.shape, y_train.shape
# Out:
# ((887, 100, 1), (887,))

# %%
import tensorflow as tf

# %%
import tensorflow as tf
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, LSTM

model = Sequential()

model.add(LSTM(50, return_sequences = True, input_shape = (100, 1)))
model.add(LSTM(50, return_sequences = True))
model.add(LSTM(50))
model.add(Dense(1))

model.compile(loss = 'mean_squared_error', optimizer = 'adam')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 100, 50)           10400
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, validation_split=0.1, epochs= 60, batch_size=64, verbose = 1)
# Out:
# Epoch 1/60
# 13/13 [==============================] - 23s 632ms/step - loss: 0.0087 - val_loss: 0.0266
# Epoch 2/60
# 13/13 [==============================] - 5s 406ms/step - loss: 0.0027 - val_loss: 0.0086
# Epoch 3/60
# 13/13 [==============================] - 5s 404ms/step - loss: 0.0017 - val_loss: 0.0098
# Epoch 4/60
# 13/13 [==============================] - 6s 431ms/step - loss: 0.0012 - val_loss: 0.0064
# Epoch 5/60
# 13/13 [==============================] - 5s 417ms/step - loss: 9.9544e-04 - val_loss: 0.0030
# Epoch 6/60
# 13/13 [==============================] - 5s 423ms/step - loss: 9.3522e-04 - val_loss: 0.0034
# Epoch 37/60
# 13/13 [==============================] - 6s 431ms/step - loss: 4.6445e-04 - val_loss: 0.0012
# Epoch 38/60
# 13/13 [==============================] - 6s 443ms/step - loss: 4.2794e-04 - val_loss: 0.0017
# Epoch 39/60
# 13/13 [==============================] - 6s 469ms/step - loss: 3.9803e-04 - val_loss: 0.0013
# Epoch 40/60
# 13/13 [==============================] - 6s 485ms/step - loss: 3.9312e-04 - val_loss: 0.0018
# Epoch 41/60
# 13/13 [==============================] - 6s 442ms/step - loss: 3.8244e-04 - val_loss: 0.0019
# Epoch 42/60
# 13/13 [==============================] - 6s 461ms/step - loss: 3.8669e-04 - val_loss: 0.0014
# Epoch 43/60
# 13/13 [==============================] - 6s 434ms/step - loss: 3.7789e-04 - val_loss: 0.0013
# Epoch 44/60
# 13/13 [==============================] - 6s 488ms/step - loss: 3.7377e-04 - val_loss: 0.0012
# Epoch 45/60
# 13/13 [==============================] - 5s 416ms/step - loss: 3.9084e-04 - val_loss: 0.0018
# Epoch 46/60
# 13/13 [==============================] - 5s 397ms/step - loss: 3.6601e-04 - val_loss: 0.0012
# Epoch 47/60
# 13/13 [==============================] - 5s 393ms/step - loss: 3.6463e-04 - val_loss: 0.0020
# Epoch 48/60
# 13/13 [==============================] - 5s 385ms/step - loss: 3.5597e-04 - val_loss: 0.0011
# Epoch 49/60
# 13/13 [==============================] - 5s 411ms/step - loss: 3.2797e-04 - val_loss: 0.0014
# Epoch 50/60
# 13/13 [==============================] - 6s 458ms/step - loss: 3.4257e-04 - val_loss: 0.0014
# Epoch 51/60
# 13/13 [==============================] - 5s 393ms/step - loss: 3.2012e-04 - val_loss: 0.0011
# Epoch 52/60
# 13/13 [==============================] - 5s 415ms/step - loss: 3.1375e-04 - val_loss: 0.0015
# Epoch 53/60
# 13/13 [==============================] - 5s 401ms/step - loss: 3.3405e-04 - val_loss: 7.3125e-04
# Epoch 54/60
# 13/13 [==============================] - 6s 424ms/step - loss: 4.1644e-04 - val_loss: 0.0023
# Epoch 55/60
# 13/13 [==============================] - 5s 422ms/step - loss: 3.4083e-04 - val_loss: 0.0011
# Epoch 56/60
# 13/13 [==============================] - 5s 395ms/step - loss: 3.1174e-04 - val_loss: 0.0011
# Epoch 57/60
# 13/13 [==============================] - 5s 395ms/step - loss: 2.8871e-04 - val_loss: 0.0014
# Epoch 58/60
# 13/13 [==============================] - 5s 404ms/step - loss: 2.8747e-04 - val_loss: 8.8048e-04
# Epoch 59/60
# 13/13 [==============================] - 6s 428ms/step - loss: 2.8289e-04 - val_loss: 0.0011
# Epoch 60/60
# 13/13 [==============================] - 6s 461ms/step - loss: 2.7299e-04 - val_loss: 9.1130e-04

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error

rmse_train = sqrt(mean_squared_error(y_train, train_predict))
rmse_test = sqrt(mean_squared_error(y_test, test_predict))
rmse_train, rmse_test
# Out:
# (0.018167400753115456, 0.0656289580506321)

# %%
train_predict = MMS.inverse_transform(train_predict)
test_predict = MMS.inverse_transform(test_predict)

# %%
look_back = 100

trainPredictPlot = np.empty_like(df_high)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back: len(train_predict) + look_back, :] = train_predict

testPredictPlot = np.empty_like(df_high)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict) + (look_back * 2) + 1: len(df_high) - 1, :] = test_predict

# %%
plt.plot(MMS.inverse_transform(df_high))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)

plt.legend(labels = ['Complete data', 'Train data', 'Predicted data'])
plt.show()
